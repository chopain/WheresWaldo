# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import pandas as pd
import numpy as np
from PIL import Image
import io

# %%
import os
# os.listdir("../Hey-Waldo/64/waldo")

# %%
ims = np.array([np.array(imread("../Hey-Waldo/64/waldo/"+fname)) for fname in os.listdir("../Hey-Waldo/64/waldo")])

# %%
plt.imshow(ims[0])

# %%
ims[3][30, 29]
# Out:
# array([154,  63,  60], dtype=uint8)

# %%
data = ims[0]

# %%
data = data.flatten('C')

# %%
data
# Out:
# array([224, 174, 212, ...,  39, 123, 169], dtype=uint8)
